# %%
# %load_ext autoreload
# %autoreload 2
import BikeSystem
import pandas as pd
import numpy as np
from IPython.display import display
import gmaps
gmaps.configure(api_key='AIzaSyCkVUk-IJZvr6Fql6NMNli64S5GFzaRgb0')

# %%
from collections import defaultdict
from RouteAnalysis import RouteAnalysis
bs = BikeSystem.NewYorkBikeSystem()
rt = RouteAnalysis(bs)
res = rt.highfreq_routes(5000)
rt.cluster(res, 3)
# Out:
# Loaded 49669470 rows from /home/jianwei/BikeAnalysis/data/NewYork/NewYork.pkl.
# Loaded 833 bike stations from NewYork.
# /home/jianwei/BikeAnalysis/RouteAnalysis.py:94: RuntimeWarning: invalid value encountered in true_divide
#   res = (b - a) / b
# ([('Liberty St & Broadway', 'South End Ave & Liberty St'),
#   ('Greenwich Ave & 8 Ave', 'W 22 St & 10 Ave'),
#   ('South End Ave & Liberty St', 'W 14 St & The High Line'),
#   ('Greenwich Ave & 8 Ave', 'Mercer St & Bleecker St'),
#   ('Christopher St & Greenwich St', 'West St & Chambers St'),
#   ('Christopher St & Greenwich St', 'W 17 St & 8 Ave'),
#   ('Kent Ave & S 11 St', 'N 6 St & Bedford Ave'),
#   ('E 58 St & 3 Ave', 'W 42 St & 8 Ave'),
#   ('E 31 St & 3 Ave', 'Pershing Square North'),
#   ('9 Ave & W 45 St', 'W 37 St & 10 Ave'),
#   ('Central Park S & 6 Ave', 'Grand Army Plaza & Central Park S'),
#   ('E 20 St & 2 Ave', 'Pershing Square North'),
#   ('9 Ave & W 18 St', '9 Ave & W 22 St'),
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-d134291e4f79> in <module>()
#       1 res = rt.highfreq_routes(5000)
# ----> 2 rt.cluster(res, 4)
#
# ~/BikeAnalysis/RouteAnalysis.py in cluster(self, res, n_cluster, **kwargs)
#      89             y1 = np.array([flow_a.get(i, 0) for i in x])
#      90             y2 = np.array([flow_b.get(i, 0) for i in x])
# ---> 91             a, b = np.min(y1, y2), np.max(y1, y2)
#      92             res = np.divide(a, b, out=np.zeros_like(a), where=b != 0)
#      93             series.append(res)
#
# /usr/local/lib/python3.5/dist-packages/numpy/core/fromnumeric.py in amin(a, axis, out, keepdims)
#    2370
#    2371     return _methods._amin(a, axis=axis,
# -> 2372                           out=out, **kwargs)
#    2373
#    2374
#
# ...

# %%
from matplotlib import pyplot as plt
freqs = rt.routes.values()
plt.hist(freqs, bins=200, range=[0, 1000])
plt.xlabel("Count")
plt.show()

# %%
len(rt.highfreq_routes(5000))
# Out:
# 973

# %%
import BikeSystem
rt.plot_route(('B.U. Central - 725 Comm. Ave.', "Packard's Corner - Commonwealth Ave at Brighton Ave"), save=False)
# Out:
# Plotting  ('B.U. Central - 725 Comm. Ave.', "Packard's Corner - Commonwealth Ave at Brighton Ave")

# %%
rt.plot_route_map(10000)
# Out:
# Figure()
